# %% [markdown]
# <a href="https://colab.research.google.com/github/maksudrakib44/60-Days-of-Python/blob/main/Linear_Regression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/maksudrakib44/machine-learning
# Out:
# Cloning into 'machine-learning'...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ML Dataset/StudentResult_vs_StudyHour.csv')

dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
x= dataset.iloc[:, :-1].values
y= dataset.iloc[:, 1].values

print(y)
# Out:
# [21 47 27 75 30 15 20 78 68 55 52 92 80 31 30 30 25 67 62 38 25 88 86 85
#  71 61 60 42 61]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 5.843994936299751
# [9.17889945]

# %%
y_pred = regressor.predict(x_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

df.head()
# Out:
#    Actual  Predicted
# 0      27  35.216473
# 1      25  31.544913
# 2      85  78.357301
# 3      31  37.970143
# 4      92  88.454090

# %%
from sklearn import metrics
print('Mean Square Error is:', metrics.mean_squared_error(y_test, y_pred) )
# Out:
# Mean Square Error is: 36.551393833386555
